# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('best_catboost_120BS_2_params.pkl', 'rb') as f:
    dic_params = pickle.load(f)

# %%
dic_params
# Out:
# OrderedDict([('bagging_temperature', 1.1644507328027726e-08),
#              ('border_count', 32),
#              ('depth', 10),
#              ('iterations', 1200),
#              ('l2_leaf_reg', 0.1),
#              ('random_strength', 10.0)])

# %%
df_results = pd.read_csv('results_catboost_120BS_2.csv')

# %%
df_results
# Out:
#      split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0             0.355889           0.355968           0.349719         0.353859
# 1             0.338053           0.348009           0.327937         0.338000
# 2             0.314060           0.316669           0.309141         0.313290
# 3             0.316174           0.316906           0.320838         0.317973
# 4             0.339438           0.345024           0.330213         0.338225
# ..                 ...                ...                ...              ...
# 115           0.498349           0.485744           0.482374         0.488822
# 116           0.478010           0.474142           0.471739         0.474630
# 117           0.484714           0.482867           0.475998         0.481193
# 118           0.488811           0.481273           0.479302         0.483129
# 119           0.481360           0.475612           0.473302         0.476758
#
# ...

# %%
df_results.mean_test_score.plot()

# %%
plt.plot(df_results.param_iterations, df_results.mean_test_score, '*')
