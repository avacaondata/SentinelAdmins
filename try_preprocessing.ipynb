# %%
from preprocessing import *
# Out:
# /home/alejandro.vaca/miniconda/envs/sentinel_env/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X, y, encoder = preprocess_data('TOTAL_TRAIN.csv', process_cat=False)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Valores unicos de CADASTRAL--- ['2' '8' '5' '6' '4' '7' '3' 'C' '1' '9' 'B' 'A' nan]
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]
# ##### GETTING COLOR VARIABLES ##########
# 100%|██████████| 4/4 [00:00<00:00,  5.23it/s]
# /home/alejandro.vaca/cajamar/SentinelAdmins/preprocessing.py:327: RuntimeWarning: invalid value encountered in true_divide
#   df["NPCRI"] = (R - B) / (R + B)
# /home/alejandro.vaca/cajamar/SentinelAdmins/preprocessing.py:328: RuntimeWarning: invalid value encountered in power
#   df["AVI"] = (N * (1 - R) * (N - R)) ** (1 / 3)
# /home/alejandro.vaca/cajamar/SentinelAdmins/preprocessing.py:330: RuntimeWarning: divide by zero encountered in true_divide
#   df["RVI"] = N / R
# /home/alejandro.vaca/cajamar/SentinelAdmins/preprocessing.py:331: RuntimeWarning: divide by zero encountered in true_divide
#   df["SR"] = R / N
# ...
