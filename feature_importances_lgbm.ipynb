# %%
import pickle
from lightgbm import plot_importance

# %%
with open('best_lightgbm_geovars_10_03_model.pkl', 'rb') as f:
    bayessearch = pickle.load(f)

# %%
type(bayessearch.best_estimator_['model'])
# Out:
# lightgbm.sklearn.LGBMClassifier

# %%
model = bayessearch.best_estimator_['model']

# %%
fig = plot_importance(model, figsize=(30, 40), ignore_zero=False)

# %%
fig.figure.savefig('feature_importances_lightgbm.png')

# %%
with open('best_LIGHTGBM_VARS_FINAL_model.pkl', 'rb') as f:
    model=pickle.load(f)

# %%
fig = plot_importance(model.best_estimator_, figsize=(30, 40), ignore_zero=False)

# %%
fig.figure.savefig('feature_importances_VARS_FINAL.png')
